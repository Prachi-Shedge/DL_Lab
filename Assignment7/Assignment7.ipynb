# %% [markdown]
#  YOLO Object Detection

# %%
pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (8.3.177)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (1.12.0)
# Requirement already satisfied: torch>=1.8.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from ultralytics) (2.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from IPython.display import display, Javascript   
from ultralytics import YOLO
import numpy as np
import base64
import io
from PIL import Image
import cv2      
def show_image(img):
    cv2.imshow("Image", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
from ultralytics import YOLO

# Load model
yolo = YOLO("yolov8s.pt")

# Open webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO tracking
    results = yolo.track(frame, stream=True)
    for result in results:
        for box in result.boxes:
            if box.conf[0] > 0.4:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cls = int(box.cls[0])
                label = f"{result.names[cls]} {box.conf[0]:.2f}"
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, label, (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    cv2.imshow("YOLOv8 Webcam", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 2 couchs, 350.7ms
# Speed: 5.1ms preprocess, 350.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 323.6ms
# Speed: 3.0ms preprocess, 323.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 290.7ms
# Speed: 1.9ms preprocess, 290.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 288.1ms
# Speed: 2.8ms preprocess, 288.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 286.6ms
# Speed: 3.1ms preprocess, 286.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 276.6ms
# Speed: 2.7ms preprocess, 276.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 294.0ms
# Speed: 2.8ms preprocess, 294.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 302.2ms
# Speed: 3.0ms preprocess, 302.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 296.3ms
# Speed: 3.2ms preprocess, 296.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 177.7ms
# Speed: 1.4ms preprocess, 177.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 182.5ms
# Speed: 1.5ms preprocess, 182.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 171.0ms
# Speed: 1.3ms preprocess, 171.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 180.2ms
# Speed: 1.6ms preprocess, 180.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 168.7ms
# Speed: 1.4ms preprocess, 168.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 179.8ms
# Speed: 1.4ms preprocess, 179.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 138.1ms
# Speed: 1.0ms preprocess, 138.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 175.1ms
# Speed: 1.5ms preprocess, 175.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 171.8ms
# Speed: 2.1ms preprocess, 171.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 145.4ms
# Speed: 1.0ms preprocess, 145.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 167.2ms
# Speed: 1.7ms preprocess, 167.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 186.1ms
# Speed: 1.3ms preprocess, 186.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 176.3ms
# Speed: 1.6ms preprocess, 176.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 164.9ms
# Speed: 1.0ms preprocess, 164.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 167.4ms
# Speed: 1.2ms preprocess, 167.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 171.7ms
# Speed: 1.4ms preprocess, 171.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 157.1ms
# Speed: 1.3ms preprocess, 157.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 157.5ms
# Speed: 1.7ms preprocess, 157.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 165.0ms
# Speed: 1.9ms preprocess, 165.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 179.4ms
# Speed: 1.2ms preprocess, 179.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 164.8ms
# Speed: 1.3ms preprocess, 164.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 166.4ms
# Speed: 2.0ms preprocess, 166.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 184.2ms
# Speed: 1.2ms preprocess, 184.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 170.8ms
# Speed: 1.1ms preprocess, 170.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
